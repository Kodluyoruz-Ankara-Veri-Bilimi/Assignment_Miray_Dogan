# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.getcwd()
os.chdir( "C:/Users/Miray/Desktop")
os.getcwd()
# Out:
# 'C:\\Users\\Miray\\Desktop'

# %%
df=pd.read_csv("odev.csv")
# Out:
# C:\Users\Miray\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (128,129) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...  ind_416  ind_418  ind_420  ind_422  ind_424   ind_426  \
# 0   17.62   11.73  ...    -49.6      -54     -152     -353      1.0  0.498547
# 1   18.16   12.22  ...    -55.6      -60     -158     -359      1.0  0.537088
# 2   17.86   12.28  ...    -58.4      -60     -160     -362      1.0  0.615169
# 3   14.76   12.61  ...    -61.8      -65     -166     -367      1.0  0.661517
# 4   11.92   14.25  ...    -79.8      -86     -186     -388      1.0  0.747204
#
#     ind_428  20_target  50_target  90_target
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6167 entries, 0 to 6166
# Columns: 136 entries, ind_5 to 90_target
# dtypes: float64(88), int64(45), object(3)
# memory usage: 6.4+ MB

# %%
df.describe().T
# Out:
#             count       mean         std         min         25%        50%  \
# ind_5      6167.0  -0.803146   23.624403 -131.000000  -14.000000   0.000000
# ind_6      6167.0  -0.803470   23.624144 -131.000000  -14.000000   0.000000
# ind_8      6167.0  48.388890   36.388526    0.000000   14.285714  50.000000
# ind_9      6167.0  48.289282   36.478009    0.000000   14.285714  50.000000
# ind_10     6167.0   0.099609   60.414625 -100.000000  -50.000000   0.000000
# ind_12     6167.0  49.488867   12.198722   12.134540   40.868503  49.549766
# ind_13     6167.0 -18.497518   68.281120 -625.093855  -45.687212  -2.817298
# ind_14     6167.0  11.771485    6.803997    1.050000    6.850000  10.550000
# ind_15     6167.0  11.773550    5.786089    1.660000    7.260000  11.040000
# ind_16     6167.0  11.773392    4.970499    2.580000    7.635000  11.270000
# ind_17     6167.0  11.772164    4.488712    3.333333    8.160000  11.426667
# ...

# %%
df.isnull().sum().rename_axis('Değişkenler').reset_index(name='Kayıp Veriler')
# Out:
#     Değişkenler  Kayıp Veriler
# 0         ind_5              0
# 1         ind_6              0
# 2         ind_8              0
# 3         ind_9              0
# 4        ind_10              0
# 5        ind_12              0
# 6        ind_13              0
# 7        ind_14              0
# 8        ind_15              0
# 9        ind_16              0
# 10       ind_17              0
# 11       ind_18              0
# 12       ind_19              0
# 13       ind_20              0
# 14       ind_21              0
# 15       ind_22              0
# 16       ind_23              0
# 17       ind_25              0
# 18       ind_26              0
# 19       ind_27              0
# 20       ind_28              0
# 21       ind_29              0
# 22       ind_30              0
# 23       ind_31              0
# 24       ind_32              0
# 25       ind_33              0
# 26       ind_34              0
# 27       ind_35              0
# 28       ind_36              0
# ...

# %%
df.dropna(axis=0, how='any', inplace=True)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.dtypes
# Out:
# ind_5          int64
# ind_6          int64
# ind_8        float64
# ind_9        float64
# ind_10       float64
# ind_12       float64
# ind_13       float64
# ind_14       float64
# ind_15       float64
# ind_16       float64
# ind_17       float64
# ind_18       float64
# ind_19         int64
# ind_20         int64
# ind_21         int64
# ind_22         int64
# ind_23         int64
# ind_25       float64
# ind_26       float64
# ind_27       float64
# ind_28       float64
# ind_29       float64
# ind_30       float64
# ind_31       float64
# ind_32       float64
# ind_33       float64
# ind_34       float64
# ind_35       float64
# ind_36       float64
# ind_37       float64
#               ...
# ind_334      float64
# ind_338      float64
# ind_340      float64
# ind_344      float64
# ind_345      float64
# ind_347      float64
# ind_349      float64
# ind_351      float64
# ind_352      float64
# ind_387      float64
# ind_392      float64
# ind_397      float64
# ...

# %%
kat_df=df.select_dtypes(include=["object"])
kat_df.head()
# Out:
#   ind_109 ind_420 ind_422
# 0   GREEN    -152    -353
# 1   GREEN    -158    -359
# 2   GREEN    -160    -362
# 3   GREEN    -166    -367
# 4   GREEN    -186    -388

# %%
columns = ['ind_109','ind_420', 'ind_422']
df.drop(columns, inplace=True, axis=1)

# %%
kat_df=df.select_dtypes(include=["object"])
kat_df.head()           # object degerleri sildik.
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
import scipy.stats as stats
import pylab

# %%
import statsmodels.api as sm
sm.qqplot (df["20_target"], line= "s") 
pylab.show()

# %%
import statsmodels.api as sm
sm.qqplot (df["50_target"], line= "s") 
pylab.show()

# %%
import statsmodels.api as sm
sm.qqplot (df["90_target"], line= "s") 
pylab.show()

# %%
df.replace('?',np.nan)
# Out:
#       ind_5  ind_6       ind_8       ind_9      ind_10     ind_12     ind_13  \
# 0        19     17  100.000000   85.714286   14.285714  72.363515  60.808814
# 1        24     19  100.000000   78.571429   21.428571  74.275883  64.366798
# 2        30     24  100.000000   71.428571   28.571429  75.140402  65.915803
# 3        37     30  100.000000   64.285714   35.714286  76.677846  68.584234
# 4        41     37  100.000000   57.142857   42.857143  81.603007  76.455495
# 5        45     41  100.000000   50.000000   50.000000  80.092497  74.144360
# 6        49     45  100.000000   42.857143   57.142857  79.625649  73.412327
# 7        51     49   92.857143   35.714286   57.142857  77.015062  69.155269
# 8        52     51   85.714286   28.571429   57.142857  71.153131  58.458047
# 9        49     52   78.571429   21.428571   57.142857  71.849045  59.819306
# 10       46     49   71.428571   14.285714   57.142857  72.414835  60.906749
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
kor=df.corr()

# %%
kor.sort_values(by=['90_target'], ascending=False)
# Out:
#               ind_5     ind_6     ind_8     ind_9    ind_10    ind_12  \
# 90_target  0.060428  0.061560 -0.006650  0.012093 -0.011307  0.043786
# 50_target  0.068989  0.069652  0.006984 -0.004053  0.006654  0.055045
# 20_target  0.060969  0.062101 -0.004126 -0.031316  0.016423  0.042550
# ind_18     0.067261  0.061331 -0.012341 -0.127658  0.069646  0.110571
# ind_17    -0.049929 -0.046324 -0.065919  0.035504 -0.061141 -0.015359
# ind_412    0.620106  0.634679  0.275687 -0.276882  0.333229  0.499789
# ind_332    0.239818  0.243800  0.091993 -0.176617  0.162050  0.229002
# ind_16    -0.041130 -0.035795  0.038862  0.152133 -0.068450 -0.018741
# ind_15    -0.026336 -0.019393  0.139612  0.240048 -0.060849 -0.020730
# ind_23     0.550404  0.487505  0.401198 -0.506541  0.547493  0.703068
# ind_77     0.622680  0.622977  0.337474 -0.336825  0.406638  0.595282
# ind_14    -0.014502 -0.006066  0.162635  0.238938 -0.046312 -0.023687
# ...

# %%
yeni_data=df[['ind_18','ind_17','ind_412','ind_332','ind_16','90_target']]

# %%
yeni_data.head()
# Out:
#    ind_18     ind_17   ind_412    ind_332  ind_16  90_target
# 0  9.1100  12.060000  0.002371  20.967742   11.73  36.997753
# 1  9.2225  11.326667  0.003074  20.800000   12.22  37.016198
# 2  9.3125  10.973333  0.003561  20.634921   12.28 -37.024805
# 3  9.4150  10.426667  0.004366  20.472441   12.61 -37.040483
# 4  9.8925  11.406667  0.004198  20.312500   14.25 -37.103503

# %%
yeni_data.describe().T
# Out:
#             count       mean        std        min        25%        50%  \
# ind_18     6167.0  11.756105   2.707619   5.177500   9.810000  11.355000
# ind_17     6167.0  11.772164   4.488712   3.333333   8.160000  11.426667
# ind_412    6167.0   0.000224   0.005660  -0.023790  -0.003230  -0.000053
# ind_332    6167.0  15.757278  31.778804   0.000000   0.000000   0.000000
# ind_16     6167.0  11.773392   4.970499   2.580000   7.635000  11.270000
# 90_target  6167.0  -3.315072  36.841541 -38.573858 -37.695273 -35.788391
#
#                  75%        max
# ind_18     13.443750  27.097500
# ind_17     14.653333  40.460000
# ind_412     0.003414   0.023340
# ind_332     0.000000  99.667774
# ind_16     14.960000  37.050000
# 90_target  37.521892  38.465649

# %%
from scipy import stats
import scipy.stats as st
from scipy.stats import shapiro
from scipy.stats import levene

# %%
dict={
                'ind_18':'ind_18',
                'ind_17':'ind_17',
                'ind_412':'ind_412',
                'ind_332': 'ind_332',
                'ind_16':'ind_16',
                '90_target':'90_target'
         }

# %%
for key in dict:
   
            stat,p=shapiro(yeni_data[dict[key]])
            alpha=0.05 #kabul edilebilir hata miktarıdır.
            if(p>alpha):
                print(dict[key],"-->Örneklem Normal (Gaussian) Dağılımdan gelmektedir (Fail to Reject H0) ", "Statistics=%.3f, p=%.3f" % (stat,p))
            else:
                 print(dict[key],"-->Örneklem Normal (Gaussian) Dağılımdan gelmemektedir (reject H0) " ,"Statistics=%.3f, p=%.3f" % (stat,p))
# Out:
# ind_18 -->Örneklem Normal (Gaussian) Dağılımdan gelmemektedir (reject H0)  Statistics=0.952, p=0.000
# ind_17 -->Örneklem Normal (Gaussian) Dağılımdan gelmemektedir (reject H0)  Statistics=0.962, p=0.000
# ind_412 -->Örneklem Normal (Gaussian) Dağılımdan gelmemektedir (reject H0)  Statistics=0.985, p=0.000
# ind_332 -->Örneklem Normal (Gaussian) Dağılımdan gelmemektedir (reject H0)  Statistics=0.537, p=0.000
# ind_16 -->Örneklem Normal (Gaussian) Dağılımdan gelmemektedir (reject H0)  Statistics=0.954, p=0.000
# 90_target -->Örneklem Normal (Gaussian) Dağılımdan gelmemektedir (reject H0)  Statistics=0.661, p=0.000
# C:\Users\Miray\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1653: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
for key in dict:
            
        a= df[dict[key]].corr(yeni_data["90_target"], method="spearman")
        print(dict[key],a)
# Out:
# ind_18 0.09409496276257831
# ind_17 0.11791137873821841
# ind_412 0.1336184194361769
# ind_332 0.06463876982287789
# ind_16 0.10200468792760883
# 90_target 0.9999999999999999

# %%
        
for key in dict:
            
        a= df[dict[key]].corr(yeni_data["90_target"], method="pearson")
        print(dict[key],a)
# Out:
# ind_18 0.14087679463003305
# ind_17 0.12927711877633324
# ind_412 0.12426474991040592
# ind_332 0.11500150512229596
# ind_16 0.10807700271588314
# 90_target 1.0

# %%
sns.scatterplot(x="ind_18", y="90_target", data=yeni_data)

# %%
sns.scatterplot(x="ind_412", y="90_target", data=yeni_data)

# %%
sns.lmplot(x="ind_18", y="90_target",data=yeni_data)

# %%
sns.lmplot(x="ind_412", y="90_target",data=yeni_data)

# %%
sns.pairplot(yeni_data,kind="reg")
sns.pairplot(yeni_data,kind="scatter")

# %%
yeni_data["ind_18"].corr(yeni_data["90_target"])
# Out:
# 0.14087679463003305

# %%
from scipy import stats
import scipy.stats as st
from scipy.stats import shapiro
from scipy.stats import levene 
import statsmodels.formula.api as smf

# %%
stat,p=shapiro(yeni_data["ind_18"])
print('Statistics=%.3f, p=%.3f' % (stat,p))
# Out:
# Statistics=0.952, p=0.000

# %%
stat,p=shapiro(yeni_data["90_target"])
print('Statistics=%.3f, p=%.3f' % (stat,p))
# Out:
# Statistics=0.661, p=0.000

# %%
stats.spearmanr(yeni_data["ind_18"],yeni_data["90_target"])
alpha=0.05
if(p>alpha):
    print('Statistics=%.3f, p=%.3f' % (stat,p), 'aralarındaki bu ilişki anlamsızdır') 
else:
    print('Statistics=%.3f, p=%.3f' % (stat,p), 'aralarında bir ilişki vardır ve bu ilişki anlamlıdır')
# Out:
# Statistics=0.661, p=0.000 aralarında bir ilişki vardır ve bu ilişki anlamlıdır

# %%
stats.levene(yeni_data["ind_18"],yeni_data["90_target"])
print('Statistics=%.3f, p=%.3f' % (stat,p))
# Out:
# Statistics=0.661, p=0.000

# %%
stats.levene(yeni_data["ind_412"],yeni_data["90_target"])
print('Statistics=%.3f, p=%.3f' % (stat,p))
# Out:
# Statistics=0.661, p=0.000

# %%
test_istatistigi, pvalue=stats.ttest_ind(yeni_data["ind_18"],yeni_data["90_target"], equal_var = False)
print('Test İstatistiği= %.4f, p-degeri = %.4f' % (test_istatistigi, pvalue)) #ilişki anlamlıdır.
# Out:
# Test İstatistiği= 32.0388, p-degeri = 0.0000

# %%
test_istatistigi, pvalue=stats.ttest_ind(yeni_data["ind_412"],yeni_data["90_target"], equal_var = False)
print('Test İstatistiği= %.4f, p-degeri = %.4f' % (test_istatistigi, pvalue)) #ilişki anlamlıdır.
# Out:
# Test İstatistiği= 7.0668, p-degeri = 0.0000

# %%
stats.probplot(yeni_data["ind_18"], dist="norm", plot=pylab) #normal probability plot, probplot'tan başka dağılım grafiklerini de görebiliriz
pylab.show()

# %%
stats.probplot(yeni_data["ind_412"], dist="norm", plot=pylab) #normal probability plot, probplot'tan başka dağılım grafiklerini de görebiliriz
pylab.show()

# %%
stat,p=shapiro(df["90_target"])
print('Statistics=%.3f, p=%.3f' % (stat,p))
# Out:
# Statistics=0.661, p=0.000

# %%
stats.spearmanr(df["ind_18"],df["90_target"])
alpha=0.05
if(p>alpha):
    print('Statistics=%.3f, p=%.3f' % (stat,p), 'aralarındaki bu ilişki anlamsızdır') 
else:
    print('Statistics=%.3f, p=%.3f' % (stat,p), 'aralarında bir ilişki vardır ve bu ilişki anlamlıdır')
# Out:
# Statistics=0.661, p=0.000 aralarında bir ilişki vardır ve bu ilişki anlamlıdır

# %%
stats.spearmanr(df["ind_412"],df["90_target"])
alpha=0.05
if(p>alpha):
    print('Statistics=%.3f, p=%.3f' % (stat,p), 'aralarındaki bu ilişki anlamsızdır') 
else:
    print('Statistics=%.3f, p=%.3f' % (stat,p), 'aralarında bir ilişki vardır ve bu ilişki anlamlıdır')
# Out:
# Statistics=0.661, p=0.000 aralarında bir ilişki vardır ve bu ilişki anlamlıdır

# %%
from scipy.stats import spearmanr

# %%
###

# %%
import statsmodels.api as sm
X= yeni_data[["ind_412"]]
X[0:5]

X= sm.add_constant(X)
X[0:5]

y=yeni_data["90_target"]
y[0:5]
# Out:
# C:\Users\Miray\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# 0    36.997753
# 1    37.016198
# 2   -37.024805
# 3   -37.040483
# 4   -37.103503
# Name: 90_target, dtype: float64

# %%
lm=sm.OLS(y,X)
modelstat=lm.fit()
modelstat.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              90_target   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     96.69
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):           1.19e-22
# Time:                        17:19:23   Log-Likelihood:                -30944.
# No. Observations:                6167   AIC:                         6.189e+04
# Df Residuals:                    6165   BIC:                         6.191e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.4961      0.466     -7.504      0.000      -4.409      -2.583
# ...

# %%
modelstat.params
# Out:
# const       -3.496130
# ind_412    808.876477
# dtype: float64

# %%
modelstat.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
print("f_pvalue:", " %.4f" % modelstat.f_pvalue)
print("fvalue:", " %.2f" % modelstat.fvalue)
print("tvalue: ", "%.2f" % modelstat.tvalues [0:1])
# Out:
# f_pvalue:  0.0000
# fvalue:  96.69
# tvalue:  -7.50

# %%
modelstat.fittedvalues[0:5] #tahminlerim
# Out:
# 0   -1.577924
# 1   -1.009319
# 2   -0.615440
# 3    0.035533
# 4   -0.100476
# dtype: float64

# %%
y[0:5] #gerçekler
# Out:
# 0    36.997753
# 1    37.016198
# 2   -37.024805
# 3   -37.040483
# 4   -37.103503
# Name: 90_target, dtype: float64

# %%
print("Target = "+ str("%.2f" % modelstat.params[0]) +str("%.2f" % modelstat.params[1]))
# Out:
# Target = -3.50808.88

# %%
print("Target = "+ str("%.2f" % modelstat.params[0]) + " + ind_412" + "*" + str("%.2f" % modelstat.params[1]))
# Out:
# Target = -3.50 + ind_412*808.88

# %%
g= sns.regplot(yeni_data["ind_412"], yeni_data["90_target"], ci=None, scatter_kws= {'color': 'r', 's':9})
g.set_title("Model Denklemi: Target=-3.50 + ind_412*808.88")
g.set_ylabel("ind_412 Çıktıları ")
g.set_xlabel("ind_412 Girdileri")
# Out:
# Text(0.5, 0, 'ind_412 Girdileri')

# %%
from sklearn.linear_model import LinearRegression
X= yeni_data[["ind_412"]]
y= yeni_data["90_target"]
reg=LinearRegression()

# %%
X= yeni_data[["ind_412"]]
y= yeni_data["90_target"]
reg=LinearRegression()
model= reg.fit(X,y)
model.predict([[0.0002]])
# Out:
# array([-3.33435475])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
lm= smf.ols('y~ X', yeni_data)
model = lm.fit()
#model summary
mse= mean_squared_error(y, model.fittedvalues)

# %%
mse
# Out:
# 1336.1234365470377

# %%
mse 
import numpy as np
rmse = np.sqrt(mse)
rmse
# Out:
# 36.55302226283126

# %%
reg.predict(X)[0:10]
y[0:10]
k_t= pd.DataFrame({"gercek_y": y[0:10], "tahmin_y": reg.predict(X)[0:10]})
k_t
# Out:
#     gercek_y  tahmin_y
# 0  36.997753 -1.577924
# 1  37.016198 -1.009319
# 2 -37.024805 -0.615440
# 3 -37.040483  0.035533
# 4 -37.103503 -0.100476
# 5 -37.098277  0.867578
# 6 -37.096740  1.153848
# 7 -37.088440  0.638251
# 8 -37.069073 -0.151390
# 9 -37.074913 -0.183529

# %%
k_t["hata"] = k_t["gercek_y"] - k_t["tahmin_y"]
k_t
# Out:
#     gercek_y  tahmin_y       hata
# 0  36.997753 -1.577924  38.575677
# 1  37.016198 -1.009319  38.025516
# 2 -37.024805 -0.615440 -36.409365
# 3 -37.040483  0.035533 -37.076016
# 4 -37.103503 -0.100476 -37.003026
# 5 -37.098277  0.867578 -37.965855
# 6 -37.096740  1.153848 -38.250587
# 7 -37.088440  0.638251 -37.726691
# 8 -37.069073 -0.151390 -36.917682
# 9 -37.074913 -0.183529 -36.891384

# %%
k_t["hata_kare"] = k_t["hata"]**2
k_t
# Out:
#     gercek_y  tahmin_y       hata    hata_kare
# 0  36.997753 -1.577924  38.575677  1488.082834
# 1  37.016198 -1.009319  38.025516  1445.939875
# 2 -37.024805 -0.615440 -36.409365  1325.641848
# 3 -37.040483  0.035533 -37.076016  1374.630975
# 4 -37.103503 -0.100476 -37.003026  1369.223967
# 5 -37.098277  0.867578 -37.965855  1441.406138
# 6 -37.096740  1.153848 -38.250587  1463.107430
# 7 -37.088440  0.638251 -37.726691  1423.303191
# 8 -37.069073 -0.151390 -36.917682  1362.915266
# 9 -37.074913 -0.183529 -36.891384  1360.974217

# %%
np.sum(k_t["hata_kare"])
# Out:
# 14055.225740322214

# %%
np.mean(k_t["hata_kare"])
# Out:
# 1405.5225740322214

# %%
np.sqrt(np.mean(k_t["hata_kare"]))
# Out:
# 37.49029973249375

# %%
model.resid[0:10]
# Out:
# 0    38.575677
# 1    38.025516
# 2   -36.409365
# 3   -37.076016
# 4   -37.003026
# 5   -37.965855
# 6   -38.250587
# 7   -37.726691
# 8   -36.917682
# 9   -36.891384
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(model.resid)

# %%
shapiro(model.resid)
# Out:
# C:\Users\Miray\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1653: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# (0.7471053600311279, 0.0)

# %%
stat, p =shapiro(model.resid)
alpha = 0.05
if p > alpha:
    print('Hatalar Normal (Gaussian) Dağılımdan gelmektedir (Fail to Reject H0)')
else:
    print('Hatalar Normal (Gaussian) Dağılımdan gelmemektedir (reject H0)')
# Out:
# Hatalar Normal (Gaussian) Dağılımdan gelmemektedir (reject H0)

# %%
#çoklu regresyon- train-test

# %%
ad= yeni_data
dfk= ad.copy()

# %%
dfk.head()
# Out:
#    ind_18     ind_17   ind_412    ind_332  ind_16  90_target
# 0  9.1100  12.060000  0.002371  20.967742   11.73  36.997753
# 1  9.2225  11.326667  0.003074  20.800000   12.22  37.016198
# 2  9.3125  10.973333  0.003561  20.634921   12.28 -37.024805
# 3  9.4150  10.426667  0.004366  20.472441   12.61 -37.040483
# 4  9.8925  11.406667  0.004198  20.312500   14.25 -37.103503

# %%
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
X= dfk.drop("90_target", axis = 1)
y= dfk["90_target"]
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size= 0.20, random_state=42)

# %%
X_train.shape
# Out:
# (4933, 5)

# %%
y_train.shape
# Out:
# (4933,)

# %%
X_test.shape
# Out:
# (1234, 5)

# %%
y_test.shape
# Out:
# (1234,)

# %%
training= dfk.copy()
training.shape # hepsi training olsaydı
# Out:
# (6167, 6)

# %%
lm= sm.OLS(y_train, X_train)

# %%
lm= sm.OLS(y_train, X_train)
model= lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:              90_target   R-squared (uncentered):                   0.036
# Model:                            OLS   Adj. R-squared (uncentered):              0.035
# Method:                 Least Squares   F-statistic:                              37.27
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):                    1.24e-37
# Time:                        15:03:14   Log-Likelihood:                         -24722.
# No. Observations:                4933   AIC:                                  4.945e+04
# Df Residuals:                    4928   BIC:                                  4.949e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model.conf_int()
# Out:
#                   0            1
# ind_18    -1.279175    -0.705194
# ind_17     0.677128     1.946910
# ind_412  647.591008  1010.519114
# ind_332    0.092219     0.157675
# ind_16    -1.205934    -0.146726

# %%
influence= model.get_influence()
influence #benim errorlarım

# %%
resid_student = influence.resid_studentized_external #normalden gelenler

# %%
(cooks,p)=influence.cooks_distance
(dffits,p)=influence.dffits
leverage=influence.hat_matrix_diag
print('Leverag v.s. Studentized Residuals')
sns.regplot(leverage, model.resid_pearson, fit_reg=False) #hatalarımın dağılımını görüyorum.
# Out:
# Leverag v.s. Studentized Residuals

# %%
dfkres = pd.concat([ad , pd.Series(model.resid, name = 'resid'), pd.Series(model.predict(), name = "predict")], axis = 1)

sns.kdeplot(np.array(dfkres.resid), bw=10)
sns.distplot(np.array(dfkres.resid), hist=False)

sm.qqplot(dfkres.resid)
plt.show()

# %%
from scipy.stats import shapiro

stat, p =shapiro(dfkres.resid)
alpha = 0.05
if p > alpha:
    print('Hatalar Normal (Gaussian) Dağılımdan gelmektedir (Fail to Reject H0)')
else:
    print('Hatalar Normal (Gaussian) Dağılımdan gelmemektedir (reject H0)')
# Out:
# Hatalar Normal (Gaussian) Dağılımdan gelmektedir (Fail to Reject H0)

# %%
resid=model.resid

# %%
plt.scatter(model.predict(), resid)

# %% [markdown]
# ### Test for collinearity-tüm değişkenler ile.

# %%
n=dfk["90_target"]
m=dfk["ind_412"]
p=dfk["ind_18"]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
lm = smf.ols("n ~ m + p" , dfk).fit() # ind_412 ve ind_18 için
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      n   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     114.9
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):           9.99e-50
# Time:                        15:04:32   Log-Likelihood:                -30879.
# No. Observations:                6167   AIC:                         6.176e+04
# Df Residuals:                    6164   BIC:                         6.178e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -26.4095      2.054    -12.860      0.000     -30.435     -22.384
# ...

# %%
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif #birbiriyle bağımlı değişkenler var.
# Out:
# [11.916278826816136,
#  63.1776265773248,
#  1.0093507951941765,
#  1.2866278069941788,
#  45.10281490633528]

# %%
dfk.corr()
# Out:
#              ind_18    ind_17   ind_412   ind_332    ind_16  90_target
# ind_18     1.000000  0.545873 -0.018460  0.160939  0.429029   0.140877
# ind_17     0.545873  1.000000 -0.036754  0.064045  0.921295   0.129277
# ind_412   -0.018460 -0.036754  1.000000  0.077782 -0.025170   0.124265
# ind_332    0.160939  0.064045  0.077782  1.000000  0.039247   0.115002
# ind_16     0.429029  0.921295 -0.025170  0.039247  1.000000   0.108077
# 90_target  0.140877  0.129277  0.124265  0.115002  0.108077   1.000000

# %%
#ind_17 ve ind_16'dan şüphelendim. ve ind_18 ile ind_17

# %%
stat,p=shapiro(dfk["ind_17"])
print('Statistics=%.3f, p=%.3f' % (stat,p))
# Out:
# Statistics=0.962, p=0.000

# %%
stat,p=shapiro(dfk["ind_16"])
print('Statistics=%.3f, p=%.3f' % (stat,p))
# Out:
# Statistics=0.954, p=0.000

# %%
stats.levene(dfk["ind_17"],dfk["ind_16"])
print('Statistics=%.3f, p=%.3f' % (stat,p))
# Out:
# Statistics=0.954, p=0.000

# %%
test_istatistigi, pvalue=stats.ttest_ind(dfk["ind_16"],dfk["ind_18"], equal_var = False)
print('Test İstatistiği= %.4f, p-degeri = %.4f' % (test_istatistigi, pvalue)) #Ho reddedilemez, yani ben bu değerlerden birini silebilirim.
# Out:
# Test İstatistiği= 0.2399, p-degeri = 0.8104

# %%
stats.levene(dfk["ind_17"],dfk["ind_18"])
print('Statistics=%.3f, p=%.3f' % (stat,p))
# Out:
# Statistics=0.954, p=0.000

# %%
test_istatistigi, pvalue=stats.ttest_ind(dfk["ind_17"],dfk["ind_18"], equal_var = False)
print('Test İstatistiği= %.4f, p-degeri = %.4f' % (test_istatistigi, pvalue)) #Ho reddedilemez, yani ben bu değerlerden birini silebilirim.
# Out:
# Test İstatistiği= 0.2406, p-degeri = 0.8099

# %%
stats.levene(dfk["ind_16"],dfk["ind_18"])
print('Statistics=%.3f, p=%.3f' % (stat,p))
# Out:
# Statistics=0.954, p=0.000

# %%
test_istatistigi, pvalue=stats.ttest_ind(dfk["ind_16"],dfk["ind_18"], equal_var = False)
print('Test İstatistiği= %.4f, p-degeri = %.4f' % (test_istatistigi, pvalue)) #Ho reddedilemez, yani ben bu değerlerden birini sil
# Out:
# Test İstatistiği= 0.2399, p-degeri = 0.8104

# %%
af= dfk
dfb= ad.copy()

# %%
dfb.head()
# Out:
#    ind_18     ind_17   ind_412    ind_332  ind_16  90_target
# 0  9.1100  12.060000  0.002371  20.967742   11.73  36.997753
# 1  9.2225  11.326667  0.003074  20.800000   12.22  37.016198
# 2  9.3125  10.973333  0.003561  20.634921   12.28 -37.024805
# 3  9.4150  10.426667  0.004366  20.472441   12.61 -37.040483
# 4  9.8925  11.406667  0.004198  20.312500   14.25 -37.103503

# %%
k=['ind_17','ind_16']

# %%
dfb.drop(k, inplace=True, axis=1)

# %%
dfb.head()
# Out:
#    ind_18   ind_412    ind_332  90_target
# 0  9.1100  0.002371  20.967742  36.997753
# 1  9.2225  0.003074  20.800000  37.016198
# 2  9.3125  0.003561  20.634921 -37.024805
# 3  9.4150  0.004366  20.472441 -37.040483
# 4  9.8925  0.004198  20.312500 -37.103503

# %%
A= dfb.drop("90_target", axis = 1)
b= dfb["90_target"]
A_train, A_test, b_train, b_test= train_test_split(A,b, test_size= 0.20, random_state=42)

# %%
A_train.shape
# Out:
# (4933, 3)

# %%
lmt= sm.OLS(b_train, A_train)

# %%
modelkk= lmt.fit()
modelkk.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:              90_target   R-squared (uncentered):                   0.032
# Model:                            OLS   Adj. R-squared (uncentered):              0.031
# Method:                 Least Squares   F-statistic:                              53.81
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):                    3.25e-34
# Time:                        15:25:35   Log-Likelihood:                         -24734.
# No. Observations:                4933   AIC:                                  4.947e+04
# Df Residuals:                    4930   BIC:                                  4.949e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
lmc = LinearRegression()
modelc = lmc.fit(A_train , b_train)

# %%
modelc.score(A_train , b_train)
# Out:
# 0.04741225797235049

# %%
##sklearn üzerinden yapalım

# %%
lm = LinearRegression()
model = lm.fit(X_train , y_train)
model.intercept_
# Out:
# -25.614976600099475

# %%
lm = LinearRegression()
model = lm.fit(X_train , y_train)
model.coef_
# Out:
# array([ 1.02766092e+00,  9.28778721e-01,  8.60696781e+02,  1.16808710e-01,
#        -2.34431924e-01])

# %%
X = dfk.drop('90_target', axis=1)
y = dfk["90_target"]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.20,random_state=42)
lm = LinearRegression()
model = lm.fit(X_train, y_train)
np.sqrt(mean_squared_error(y_train, model.predict(X_train)))
np.sqrt(mean_squared_error(y_test, model.predict(X_test)))
model.score(X_train, y_train)  #modelin tahmin gücü
# Out:
# 0.05238943565573928

# %%
np.sqrt(mean_squared_error(y_train , model.predict(X_train)))
# Out:
# 35.87481048827778

# %%
np.sqrt(mean_squared_error(y_test, model.predict(X_test)))
# Out:
# 36.27024168837217

# %%
model.score(X_train , y_train)
# Out:
# 0.05238943565573928

# %%
cross_val_score(model, X_train, y_train, cv = 10, scoring = "r2").mean() #farklı farklı ayırdığı sample'lardaki cross validaiton ortalamalrı
# Out:
# 0.045017692323064386

# %%
np.sqrt(-cross_val_score(model,  X_train, y_train,cv = 10, scoring = "neg_mean_squared_error")).mean()
# Out:
# 35.929006747227966

# %%
np.sqrt(-cross_val_score(model, X_test,  y_test, cv = 10,  scoring = "neg_mean_squared_error")).mean()
# Out:
# 36.3563182926233

# %%
#Tüm data

# %%
ap= df
dfe= ap.copy()

# %%
dfe.head()
# Out:
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...   ind_412  ind_414  ind_416  ind_418  ind_424  \
# 0   17.62   11.73  ...  0.002371      2.0    -49.6      -54      1.0
# 1   18.16   12.22  ...  0.003074      0.8    -55.6      -60      1.0
# 2   17.86   12.28  ...  0.003561      2.7    -58.4      -60      1.0
# 3   14.76   12.61  ...  0.004366      0.9    -61.8      -65      1.0
# 4   11.92   14.25  ...  0.004198      0.1    -79.8      -86      1.0
#
#     ind_426   ind_428  20_target  50_target  90_target
# ...

# %%
O= dfe.drop("90_target", axis = 1)
m= dfe["90_target"]
O_train, O_test, m_train, m_test= train_test_split(O,m, test_size= 0.20, random_state=42)

# %%
lmq= sm.OLS(m_train, O_train)
modelq= lmq.fit()
modelq.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:              90_target   R-squared (uncentered):                   0.897
# Model:                            OLS   Adj. R-squared (uncentered):              0.894
# Method:                 Least Squares   F-statistic:                              316.7
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):                        0.00
# Time:                        15:31:15   Log-Likelihood:                         -19207.
# No. Observations:                4933   AIC:                                  3.868e+04
# Df Residuals:                    4801   BIC:                                  3.954e+04
# Df Model:                         132
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
lmh = LinearRegression()
modelh = lmh.fit(O_train , m_train)

# %%
modelh.score(O_train , m_train)
# Out:
# 0.8962652684738878
